# %% [markdown]
# # UJIAN TENGAH SEMESTER (UTS) (TIPE SOAL: A1)
# # ALGORITMA STRUKTUR DATA
# ## Program Studi Informatika (UMKT)
# ### Semester Genap 2024-2025

# %% [markdown]
# ---
# <strong><em> Visi Prodi TI UMKT:
#
# "Pada tahun 2037, menjadi program studi yang unggul dalam teknologi informasi dan algoritma komputasi untuk penyelesaian permasalahan sosial dan lingkungan dengan berlandaskan nilai-nilai keislaman"
#  </em></strong>
#
# ---

# %% [markdown]
# ## Instruksi Ujian
# <blockquote>
# Durasi Ujian: 90 menit
#
# Aturan:
# - Setiap mahasiswa mendapatkan jenis soal yang berbeda sesuai dengan nim
# - Sifat ujian semi-tertutup, tidak boleh membuka apapun selain soal ini tetapi mahasiswa boleh membuka catatan
# - Baca dengan teliti instruksi soal sebelum mengerjakan
# - Isi jawaban di tempat yang telah disediakan
# - Mahasiswa hanya boleh membawa laptop (boleh memakai komputer lab) dan pulpen (untuk absensi)
# - Dilarang menggunakan peralatan komunikasi (HP/smartphone)
# - Mahasiswa masuk kedalam ruangan 10 menit untuk persiapan ujian (komputer/laptop dan download soal)
# - Mahasiswa yang terlambat tidak akan mendapatkan waktu tambahan
# - Bagi mahasiswa yang tidak dapat mengikuti ujian, dapat menghadap langsung ke dosen pengampu untuk pengganti ujian dan membawa surat permohonan ujian susulan yang di tanda tangani dosen PA
# - Bagi mahasiswa yang berbuat kecurangan/kerja sama akan diberikan nilai akhir E.
# - Mahassiwa dilarang menggunakan AI dan sejenisnya.
# </blockquote>
#
# ---

# %% [markdown]
# ## Identitas Peserta

# %% [markdown]
# NAMA    : Malik Sabarullah Akbar
#
# NIM     : 2411102441250
#
# KELAS   : B

# %% [markdown]
# ---

# %% [markdown]
# ## Soal 1 (Pengertian Strategi yang Digunakan) (30 Point Total) 15 menit

# %% [markdown]
# <blockquote>
# 1(A) Jelaskan pengertian mengenai strategi algoritma Brute Force dimana jawaban Anda dalam bentuk uraian yang jelas dan sistematis berdasarkan poin-poin berikut.:</br>
#
# - Jelaskan apa yang dimaksud dengan strategi algoritma Brute Force.
# (Apa prinsip dasar dan cara kerja umum dari strategi ini? (10 Point)</br>
# - Berikan satu contoh kasus nyata atau sederhana di mana strategi Brute Force dapat digunakan (10 Point).</br>
# - Menurut Anda, pada jenis permasalahan seperti apa strategi Brute Force cocok digunakan? (10 Point)</br>
#
# </blockquote>

# %% [markdown]
# <blockquote>
# (1A) Jawaban :
#
# - Brute force adalah strategi yang melakukan penyelesaian masalah dengan satu persatu. Contohnya saat melakukan pencarian angka yang ada di array [1,2,3,4,5,6,7] dan angka yang di cari adalah angka 6, maka strategi ini akan mencari angka tersebut satu persatu dari array ke 0 sampai ke n. Dan angka yang di cari berada di index ke 5.
#
# - Pada studi kasus nyata pada strategi brute force ialah seperti membuka pintu rumah yang memiliki banyak kunci yang kita tidak ketahui yang mana kunci yang benar, maka kita perlu mencobanya satu persatu hingga pintu terbuka.
#
# - Brute force cocok digunakan pada masalah searching dengan data yang kecil. Karena strategi ini memiliki kompleksitas waktu O(n^2), jika data yang dicari berada di jumlah n yang banyak jumlahnya, maka pencarian akan kompleksitas waktunya akan meningkat atau disebut rekursif.
# </blockquote>

# %% [markdown]
# ---

# %% [markdown]
# ## Soal 2 (Desain Algoritma) (35 Point Praktikum & Teori) 20 menit

# %% [markdown]
# # 🐉 Desain Algoritma Brute Force: *Mencari Dragon Ball Tercepat*
#
# ---
#
# ## 📖 Deskripsi Kasus
# Son Goku sedang dalam misi untuk mengumpulkan ketujuh **Dragon Ball** yang tersebar di berbagai wilayah.
# Setiap Dragon Ball memiliki lokasi berbeda dengan jarak tertentu dari titik awal Goku.
#
# Karena Goku belum menggunakan teknik teleportasi **Instant Transmission**, ia harus memilih rute perjalanan secara manual.
# Namun, Goku ingin tahu:
# > **Berapa jarak minimum yang harus ia tempuh untuk mengunjungi semua Dragon Ball dan kembali ke titik awal?**
#
# ---
#
# ## 🎯 Tugas ANDA!!! (35 Point)
# Rancang sebuah algoritma brute force untuk menentukan rute terpendek yang memungkinkan Goku mengunjungi seluruh Dragon Ball dan kembali ke titik awal. Desain algoritma tersebut harus didasarkan pada konsep brute force yang telah Anda jelaskan sebelumnya. Hitung total jarak untuk setiap kemungkinan rute perjalanan, kemudian tentukan rute dengan jarak minimum sebagai hasil akhir. Jelaskan rancangan algoritma tersebut dalam bentuk pseudocode atau narasi penjelasan yang runtut. Selanjutnya, lakukan analisis terhadap langkah-langkah algoritma yang Anda buat dan berikan kesimpulan mengenai kelebihan serta kekurangannya.
#
# ---
#
# ## 💡 Contoh Data
# Misalkan terdapat 4 lokasi Dragon Ball:
# (DB1, DB2, DB3, DB) </br>
# Visual peta rute dan jarak antar rute dapat dilihat pada output program dibawah

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

G = nx.Graph()
edges = [
    ('DB1', 'DB2', 5),
    ('DB1', 'DB3', 9),
    ('DB1', 'DB4', 8),
    ('DB2', 'DB3', 7),
    ('DB2', 'DB4', 6),
    ('DB3', 'DB4', 4)
]
G.add_weighted_edges_from(edges)

pos = nx.circular_layout(G)

plt.figure(figsize=(7,7))
nx.draw_networkx_nodes(G, pos, node_size=2500, node_color='lightblue', edgecolors='black')
nx.draw_networkx_edges(G, pos, width=2)
nx.draw_networkx_labels(G, pos, font_size=12, font_weight='bold')

for (n1, n2, w) in G.edges(data='weight'):
    x1, y1 = pos[n1]
    x2, y2 = pos[n2]
    xm, ym = (x1 + x2) / 2, (y1 + y2) / 2
    dx, dy = x2 - x1, y2 - y1
    norm = np.sqrt(dx**2 + dy**2)
    nx_, ny_ = -dy / norm, dx / norm
    if ny_ < 0: nx_, ny_ = -nx_, -ny_
    offset = 0.08
    plt.text(xm + nx_ * offset, ym + ny_ * offset, str(w),
             fontsize=11, fontweight='bold', color='black',
             bbox=dict(boxstyle="round,pad=0.2", fc="white", ec="none"))

plt.title("Graf Jarak Antar Dragon Ball", fontsize=14, fontweight='bold')
plt.axis('off')
plt.show()

# %% [markdown]
# <blockquote>
# (2A) Jawaban :
#
# Kemungkinan rute yang di dapatkan ada 6 kemungkinan, karena
#
# ```python
# (n-1)!f
# (4-1)!f
# 3! = 3 * 2 * 1 = 6
# ```
#
# Inilah kemungkinan si Goku untuk memilih rutenya untuk mengambil rute minimum :
#
# - Jika dimulai dari DB2 -> DB4 -> DB1 -> DB3 -> DB2 maka menghasilkan 9 + 8 + 6 + 7 = 30 rute
# - Jika dimulai dari DB2 -> DB4 -> DB3 -> DB1 -> DB2 maka menghasilkan 9 + 4 + 6 + 5 = 24 rute (Jumlah Minimum)
#
# - Jika dimulai dari DB2 -> DB3 -> DB1 -> DB4 -> DB2 maka menghasilkan 7 + 6 + 8 + 9 = 30 rute
# - Jika dimulai dari DB2 -> DB3 -> DB4 -> DB1 -> DB2 maka menghasilkan 7 + 4 + 8 + 5 = 24 rute
#
# - Jika dimulai dari DB2 -> DB1 -> DB3 -> DB4 -> DB2 maka menghasilkan 5 + 6 + 4 + 9 = 24 rute
# - Jika dimulai dari DB2 -> DB1 -> DB4 -> DB3 -> DB2 maka menghasilkan 5 + 8 + 4 + 7 = 24 rute
#
# langkah tersebut saya lakukan agar bisa menemukan rute minimum dari pencarian Dragon ball dengan strategi Brute Force.<br>
# Goku menemukan rute minimum, yaitu memulai perjalanannya dari DB1 ke DB4 dengan jumlah rute 8, selanjutnya goku pergi ke DB3 dari DB4 dengan jumlah rute 4, selanjutnya goku ke DB2 dari DB3 dengan rute 7, perjalanan terakhirnya goku pergi ke DB1 dari DB3 dengan jumlah rute 5. Jadi Goku melakukan perjalanannya dengan cepat untuk mendapatkan semua Dragon Ball dengan jumlah rute 8 + 4 + 7 + 5 = 24 rute.
#
# Pada Brute force keleibihannya ialah mencari nilai minimum dari rutenya dengan satu persatu dengan baik. Tetapi kekurangan dari brute force yaitu pada kompleksitas waktunya O(n^2) jika data berjumlah besar dan pencarian berada di akhir dari n maka waktu yang di butuhkan untuk mencari data tersebut akan lebih lama ketimbang dengan data yang di cari berada di awal data.
#
# </blockquote>

# %% [markdown]
# ---

# %% [markdown]
# ## Soal 3 Analisis Kasus Terbaik dan Terburuk (35 Point) 25 menit

# %% [markdown]
# Gunakan hasil desain dan implementasi algoritma anda yang telah anda buat sebelumnya pada soal 2A. tuliskan penjelasan secara **Jelas** dan **Logis**. </br>
#
# ### 1. Kasus Terbaik (Best Case) (17,5 Point)
# Jelaskan seperti apa kondisi terbaik dari desain algoritma yang anda buat, mengapa kondisi tersebut dianggap sebagai kasus terbaik, dan bagaimana algoritma bekerja pada kondisi tersebut secara singkat dan jelas.
#
# ### 2. Kasus Terbaik (Worst Case) (17,5 Point)
# Jelaskan seperti apa kondisi terburuk dari algoritma yang Anda buat, mengapa kondisi tersebut menyebabkan algoritma bekerja paling lambat atau tidak efisien.
# gambarkan kondisi tersebut.

# %% [markdown]
# <blockquote>
# (3A) Jawaban :
#
# 1. (Best Case) : Kasus terbaiknya ialah saat rute berjumlah minimum atau 24 rute yang terbaik dengan semua Dragon Ball di dapatkan, jadi Goku memulai perjalanannya dari DB1 ke DB4 dengan jumlah rute 8, selanjutnya goku pergi ke DB3 dari DB4 dengan jumlah rute 4, selanjutnya goku ke DB2 dari DB3 dengan rute 7, perjalanan terakhirnya goku pergi ke DB1 dari DB3 dengan jumlah rute 5. Jadi Goku melakukan perjalanannya dengan cepat untuk mendapatkan semua Dragon Ball dengan jumlah rute 8 + 4 + 7 + 5 = 24 rute, sehingga goku mendapatkan semua Dragon Ball lebih cepat dengan rute tersebut.
#
# 2. (Worst Case) : Kasus terburuknya berada di rute yang banyak, dari kasus analisis yang saya cari rute yang berjumlah besar iyalah 30 rute. Hal tersebut terjadi jika Goku mengambil rute dari DB2 -> DB4 -> DB1 -> DB3 -> DB2 maka menghasilkan 9 + 8 + 6 + 7 = 30 rute. Hal tersebut membuat Goku mendapatkan Dragon Ball sedikit lebih lama ketimbangkan dengan kasus terbaik (Best Case) karena brute force menggunakan kompleksitas waktu O(n^2) secara rekursif.
# </blockquote>

# %% [markdown]
# ---

# %% [markdown]
# ## Instruksi Pengumpulan
#
# <blockquote>
# Kumpulkan file ini dengan format berikut:
#
# <span style="font-family:Comic Sans MS">"SOAL_X_NIM.ipynb"</span>
#
#
# <em> Ganti X dengan tipe soal yang anda dapat sesuai dengan nim! </em>
#
# Silahkan kumpulkan di tempat yang telah disediakan.
# </blockquote>
#
# ---
